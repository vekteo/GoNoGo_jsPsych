# %% [markdown]
# <a href="https://colab.research.google.com/github/vekteo/GoNoGo_jsPsych/blob/main/GoNoGo_jsPsych_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Code for preprocessing the Go/No-Go task (jsPsych)**
#
# 1. Click the FOLDER ikon in the left column (last icon)
# 2. In the opening window, click the UPLOAD icon (first icon) (if another window opens before this step, click OK)
# 3. In the opening window, choose the Go/No-Go outputs for the upload (e.g., "_Subject_01_Session_1_output.csv")
# 4. Run the coe with the Runtime --> Run all option
# 5. If the code runs correctly, it will download a .csv file to your local machine
# ---
#
#
#
# ---

# %%
import glob
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
from google.colab import files

# %%
# get data file names
filenames = glob.glob("*.csv")
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, encoding='ISO-8859-1'))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)
big_frame
# Out:
#      ï»¿Event Index  UTC Timestamp  ... STAT_p_incorrect_NoGo  STAT_dprime
# 0                 1   1.644082e+12  ...                   NaN          NaN
# 1                 2   1.644082e+12  ...                   NaN          NaN
# 2                 3   1.644082e+12  ...                   NaN          NaN
# 3                 4   1.644082e+12  ...                   NaN          NaN
# 4                 5   1.644082e+12  ...                   NaN          NaN
# ...             ...            ...  ...                   ...          ...
# 1703            566   1.643920e+12  ...                   NaN          NaN
# 1704            567   1.643920e+12  ...                   NaN          NaN
# 1705            568   1.643920e+12  ...                0.3125     1.614183
# 1706            569   1.643920e+12  ...                   NaN          NaN
# 1707    END OF FILE            NaN  ...                   NaN          NaN
#
# [1708 rows x 60 columns]

# %%
#leave only the important columns
df = big_frame.loc[:, ['Participant Public ID', 'STAT_total_correct',	'STAT_total_error',	'STAT_mean_accuracy',	'STAT_nr_correct_Go','STAT_nr_correct_NoGo','STAT_nr_incorrect_Go','STAT_nr_incorrect_NoGo','STAT_p_correct_Go','STAT_p_correct_NoGo','STAT_p_incorrect_Go','STAT_p_incorrect_NoGo', 'STAT_dprime']]
df.head()
# Out:
#   Participant Public ID  STAT_total_correct  ...  STAT_p_incorrect_NoGo  STAT_dprime
# 0              mxs1w0o7                 NaN  ...                    NaN          NaN
# 1              mxs1w0o7                 NaN  ...                    NaN          NaN
# 2              mxs1w0o7                 NaN  ...                    NaN          NaN
# 3              mxs1w0o7                 NaN  ...                    NaN          NaN
# 4              mxs1w0o7                 NaN  ...                    NaN          NaN
#
# [5 rows x 13 columns]

# %%
#drop instruction, feedback trials
df = df.dropna(subset=['STAT_total_correct'])
df.head()
# Out:
#      Participant Public ID  ...  STAT_dprime
# 567               mxs1w0o7  ...     0.427573
# 1136              5kwv1ykm  ...     0.737834
# 1705              x07ksd1p  ...     1.614183
#
# [3 rows x 13 columns]

# %%
#save data
df.to_csv("gonogo.csv",index=False)
files.download("gonogo.csv")
